# %% [markdown]
# # Proyecto Integrador – Minería de Datos I
#
# # Notebook 5
#
# # Conclusiones Finales
#
# ---
#
# ## Integrantes
#
# - Marcia Lovaiza
# - .....................................
#
# ## Materia
# - Minería de Datos I
#
# ## Fecha
#
# - 30-06-2026
#
# ---
#
# # Introducción
#
# En este último notebook se presentan las conclusiones obtenidas durante el desarrollo del Proyecto Integrador.
#
# Se resumen los principales hallazgos encontrados durante la inspección inicial, la preparación de datos, el análisis exploratorio y la aplicación del Análisis de Componentes Principales (PCA).
#
# Asimismo, se identifican las limitaciones del estudio y posibles líneas de trabajo futuras.

# %% [markdown]
# # Objetivos alcanzados
#
# Durante el desarrollo del proyecto fue posible cumplir los objetivos planteados inicialmente.
#
# Se realizó un proceso completo de inspección, preparación y análisis del conjunto de datos, documentando todas las transformaciones efectuadas y garantizando la trazabilidad del proceso mediante un registro ETL.
#
# Posteriormente se desarrolló un análisis exploratorio que permitió comprender el comportamiento de las variables y finalmente se aplicó la técnica de reducción de dimensionalidad PCA.

# %%
import pandas as pd

df = pd.read_json("../data/processed/streaming_users_clean.json")

df.head()

# %% [markdown]
# # Resumen del proceso realizado
#
# El proyecto fue desarrollado siguiendo las principales etapas del proceso de Minería de Datos:
#
# - Inspección inicial del conjunto de datos.
# - Identificación de problemas de calidad.
# - Limpieza y normalización de variables.
# - Tratamiento de valores faltantes.
# - Conversión de tipos de datos.
# - Generación del registro ETL.
# - Análisis exploratorio mediante visualizaciones.
# - Aplicación del Análisis de Componentes Principales (PCA).
# - Elaboración de conclusiones.

# %% [markdown]
# # Principales hallazgos
#
# Durante el análisis se identificaron diversos aspectos relevantes:
#
# - Existían inconsistencias en variables categóricas que fueron corregidas mediante procesos de normalización.
#
# - Se detectaron valores faltantes que fueron tratados utilizando técnicas de imputación apropiadas para cada tipo de variable.
#
# - El análisis exploratorio permitió identificar diferencias en el comportamiento de los usuarios según el plan de suscripción y el país.
#
# - La aplicación de PCA permitió resumir la información contenida en las variables numéricas conservando gran parte de la variabilidad del conjunto de datos.

# %% [markdown]
# # Limitaciones
#
# Si bien el conjunto de datos permitió desarrollar todas las etapas del proyecto, presenta algunas limitaciones:
#
# - Información limitada sobre los usuarios.
# - Variables categóricas con inconsistencias de origen.
# - Presencia de valores faltantes.
# - Escasa información temporal para realizar análisis evolutivos.

# %% [markdown]
# # Mejoras futuras
#
# Como posibles líneas de trabajo futuras se propone:
#
# - Incorporar nuevas variables relacionadas con hábitos de consumo.
#
# - Implementar modelos predictivos utilizando técnicas de Machine Learning.
#
# - Aplicar algoritmos de clustering para segmentar usuarios.
#
# - Comparar diferentes técnicas de reducción de dimensionalidad.
#
# - Incorporar mayor cantidad de registros para mejorar la representatividad del conjunto de datos.

# %% [markdown]
# # Reflexión sobre el proceso
#
# El desarrollo de este proyecto permitió aplicar de forma integrada los conocimientos adquiridos durante la asignatura.
#
# Además de aprender a utilizar herramientas de análisis de datos, también se fortalecieron habilidades relacionadas con la preparación de datos, interpretación de resultados, documentación del proceso y comunicación de conclusiones.

# %% [markdown]
# # Conclusión Final
#
# El Proyecto Integrador permitió desarrollar un proceso completo de análisis de datos siguiendo las principales etapas de una metodología de Minería de Datos.
#
# La preparación del conjunto de datos constituyó una etapa fundamental para garantizar la calidad del análisis posterior.
#
# El análisis exploratorio permitió comprender el comportamiento general de los usuarios y detectar patrones relevantes.
#
# Finalmente, la aplicación del Análisis de Componentes Principales facilitó una representación más compacta de la información contenida en las variables numéricas.
#
# En conjunto, el proyecto demuestra la importancia de un proceso sistemático de preparación y análisis de datos para obtener información confiable que apoye la toma de decisiones.

# %% [markdown]
# # Cierre del Proyecto
#
# Con la finalización de este notebook concluye el Proyecto Integrador de Minería de Datos I.
#
# Los resultados obtenidos evidencian la importancia de la calidad de los datos como etapa previa a cualquier proceso analítico y muestran cómo las técnicas de análisis exploratorio y reducción de dimensionalidad permiten transformar datos en información útil para apoyar la toma de decisiones.
#
# El proyecto queda preparado para su publicación en GitHub y su visualización mediante una aplicación desarrollada en Streamlit.
